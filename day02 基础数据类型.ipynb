# %% [markdown]
# # Python的基础数据类型

# %% [markdown]
# ## 1. 字符串string

# %% [markdown]
# * 用`' '`,`" "`,`""" """`括起来的常量
# * 字符串内有引号的，可以利用反斜杠`\`进行转义.
# * `""" """`可以直接分行

# %% [markdown]
# ## 2. 整数

# %% [markdown]
# 整数英文为 integer 。代码中的整数跟我们平常认识的整数一样，包括正整数、负整数和零，是没有小数点的数字。

# %% [markdown]
# ![image.png](attachment:cc2e06fe-6344-4440-b9a4-b446584361e2.png)

# %% [markdown]
# ## 3. 浮点数float

# %% [markdown]
# ## 4. 布尔值

# %% [markdown]
# ## 5. 空值

# %% [markdown]
# 基本上每种编程语言都有自己的特殊值——空值，在 Python 中，用 None 来表示

# %% [markdown]
# # 基本数据类型转换

# %% [markdown]
# ![image.png](attachment:98b721c8-1764-4a02-b553-c58e4566f061.png)
